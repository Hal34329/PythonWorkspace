# %%
from gtts import gTTS
from IPython.display import Audio

def speak(text, language='is'):
  tts = gTTS(text=text, lang=language, slow=False)
  tts.save("output.mp3")
  return Audio("output.mp3", autoplay=True)

# Ejemplo de uso
speak("Ég er að læera íslensku.")
# Out:
#                 <audio  controls="controls" autoplay="autoplay">
#                     <source src="data:audio/mpeg;base64,..." type="audio/mpeg" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
x = input("Frase:")
speak(x)
# Out:
#                 <audio  controls="controls" autoplay="autoplay">
#                     <source src="data:audio/mpeg;base64,..." type="audio/mpeg" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
import os

def say_hello():
    return "Hello World! I'm a python script!"

def test(message):
    directory = os.getcwd()
    return message + ": " + directory

print(test("Hola"))
print(say_hello())
# Out:
# Hola: c:\Users\HP\Documents\2024\Python\GitKraken\PythonWorkspace\Modelo residencias
# Hello World! I'm a python script!
