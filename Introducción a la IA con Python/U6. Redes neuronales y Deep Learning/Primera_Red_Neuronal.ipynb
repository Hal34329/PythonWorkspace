# %%
import pandas as pd

datos = pd.read_csv("U6_01_celsius.csv")

# %%
datos.head()
# Out:
#    celsius  fahrenheit
# 0      -40       -40.0
# 1      -10        14.0
# 2        0        32.0
# 3        8        46.4
# 4       15        59.0

# %%
datos["celsius"].values
# Out:
# array([-40, -10,   0,   8,  15,  22,  38])

# %%
X = datos["celsius"].values
y = datos["fahrenheit"].values

# %%
import tensorflow as tf

modelo = tf.keras.Sequential([
    tf.keras.layers.Input(shape=(1,)), #La entrada, los Celsius: 1 solo dato
    tf.keras.layers.Dense(units=1), #La salida. También es un dato, los grados Farenheit
])

modelo.compile(
    optimizer=tf.keras.optimizers.Adam(0.1),
    loss='mean_squared_error'
)

# %%
entrenamiento = modelo.fit(X, y, epochs=1000)
# Out:
# Epoch 1/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 579ms/step - loss: 1108.7799
# Epoch 2/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - loss: 1054.8982
# Epoch 3/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - loss: 1012.8217
# Epoch 4/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - loss: 982.4070
# Epoch 5/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 962.9438
# Epoch 6/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - loss: 952.8913
# Epoch 7/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 949.7373
# Epoch 8/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 950.2424
# Epoch 9/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 951.1740
# Epoch 10/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 950.1608
# Epoch 11/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - loss: 946.1096
# Epoch 12/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 939.0596
# Epoch 13/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - loss: 929.7580
# Epoch 14/1000
# ...

# %%
import matplotlib.pyplot as plt

plt.xlabel("# Epoca")
plt.ylabel("Magnitud de pérdida")
plt.plot(entrenamiento.history["loss"])

# %%
import numpy as np

c = 1230
prediccion = modelo.predict(np.array([c]))
print(f"Predicción: {c} Celsius son {prediccion[0]} Fahrenheit")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# Predicción: 1230 Celsius son [2246.2063] Fahrenheit

# %%
print(modelo.layers[0].get_weights())
# Out:
# [array([[1.8001856]], dtype=float32), array([31.978024], dtype=float32)]

# %%
# Cálculo real para convertir Celsius a Fahrenheit es
# (C * 1.8) + 32

# %%
# Backpropagation / Propagación hacia atrás
